# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email']
df.set_index('email', inplace=True)
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
df.loc['CoreyMSchafer@gmail.com', 'last']
# reset of the index a default
df.reset_index(inplace=True)
df.iloc[0]
# Out:
# email    CoreyMSchafer@gmail.com
# first                      Corey
# last                     Schafer
# Name: 0, dtype: object

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %% [markdown]
# use the data of the stackflow

# %%
# way of the set the columns as a index column
# add a index_col= "col_name"
ds = pd.read_csv(r"C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_public.csv", index_col="ResponseId")
ds.head(8)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# 7              35-44 years old
# 8              18-24 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# ...

# %%
# way of the set the columns as a index column
ds.set_index("Age",inplace=True)
ds
ds
# Out:
#                                         MainBranch           Employment  \
# Age
# Under 18 years old  I am a developer by profession  Employed, full-time
# 35-44 years old     I am a developer by profession  Employed, full-time
# 45-54 years old     I am a developer by profession  Employed, full-time
# 18-24 years old              I am learning to code   Student, full-time
# 18-24 years old     I am a developer by profession   Student, full-time
# ...                                            ...                  ...
# 18-24 years old     I am a developer by profession  Employed, full-time
# 25-34 years old     I am a developer by profession  Employed, full-time
# 25-34 years old     I am a developer by profession  Employed, full-time
# 18-24 years old     I am a developer by profession  Employed, full-time
# 18-24 years old        I code primarily as a hobby   Student, full-time
#
#                                               RemoteWork   Check  \
# Age
# ...
