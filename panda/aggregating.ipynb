# %% [markdown]
# Grouping and Aggreating

# %%
import pandas as pd

# %%
df = pd.read_csv(r'data/survey_results_public.csv')
schema_df = pd.read_csv(r'data/survey_results_schema.csv')

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df["YearsCode"].head(10)
# Out:
# 0    NaN
# 1     20
# 2     37
# 3      4
# 4      9
# 5     10
# 6      7
# 7      1
# 8     20
# 9     15
# Name: YearsCode, dtype: object

# %%
# for i in range(len(df["YearsCode"])):
#     if (pd.isna(df.loc[i, "YearsCode"]) | df.loc[i, "YearsCode"][-1:-6]=="years") :  # Correct check for NaN
#         pass  # Skip NaN values
#     else:
#         df.loc[i, "YearsCode"] = int(df.loc[i, "YearsCode"])  # Convert valid values to integer


# df["YearsCode"].median()

# %%
# it ignore the NaN value
print(df["JobSatPoints_1"].mean())
df["CompTotal"].median()
# Out:
# 18.5810939844496
# np.float64(110000.0)

# %%
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %%
df["CompTotal"].describe()
# Out:
# count     3.374000e+04
# mean     2.963841e+145
# std      5.444117e+147
# min       0.000000e+00
# 25%       6.000000e+04
# 50%       1.100000e+05
# 75%       2.500000e+05
# max      1.000000e+150
# Name: CompTotal, dtype: float64

# %%
group =df.groupby(["Country"])

# %%
# return all the information of those have country India
group.get_group("India")
# Out:
# C:\Users\YASH JAIN\AppData\Local\Temp\ipykernel_13464\2192109607.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   group.get_group("India")
#        ResponseId                                         MainBranch  \
# 17             18                     I am a developer by profession
# 58             59  I am not primarily a developer, but I write co...
# 75             76                              I am learning to code
# 89             90                              I am learning to code
# 96             97                     I am a developer by profession
# ...           ...                                                ...
# 65339       65340  I am not primarily a developer, but I write co...
# 65383       65384                              I am learning to code
# ...

# %%
# show the count of operating system use in the specific country

filt = df["Country"]=="India"
df.loc[filt]["OpSysPersonal use"].value_counts()
# Out:
# OpSysPersonal use
# Windows                                                                                                                                    831
# MacOS                                                                                                                                      275
# Android;Windows                                                                                                                            258
# Ubuntu;Windows                                                                                                                             239
# Ubuntu                                                                                                                                     186
#                                                                                                                                           ...
# ...

# %%
# normalize=True give the percetage form of a value count
group["OpSysPersonal use"].value_counts(normalize=True)
# Out:
# Country      OpSysPersonal use
# Afghanistan  Windows                                            0.195122
#              Android;Windows                                    0.097561
#              Other (please specify):                            0.097561
#              Arch                                               0.073171
#              AIX                                                0.048780
#                                                                   ...
# Zimbabwe     MacOS;Windows                                      0.038462
#              MacOS;Windows;Windows Subsystem for Linux (WSL)    0.038462
#              Other Linux-based;Ubuntu;Windows                   0.038462
#              Ubuntu;Windows                                     0.038462
#              iOS;MacOS                                          0.038462
# Name: proportion, Length: 11563, dtype: float64

# %%
# how much percent people use Python in Country
# con = input("Enter the country name: ")
filt1 = df["Country"]=="India"
# df.loc[filt1]["LanguageHaveWorkedWith"].str.contains("Python").value_counts().sum()
df.loc[filt1, "LanguageHaveWorkedWith"].str.contains("Python", na=False).sum()
# Out:
# np.int64(2128)

# %%
# use aggration function
# return 
group["CompTotal"].agg(["median","mean"])
# Out:
#                                            median          mean
# Country
# Afghanistan                               26000.0  4.166667e+51
# Albania                                   90000.0  1.493638e+06
# Algeria                                  600000.0  7.415032e+05
# Andorra                                   40000.0  9.400000e+04
# Angola                                  1350000.0  3.412757e+07
# ...                                           ...           ...
# Venezuela, Bolivarian Republic of...      12600.0  2.091343e+04
# Viet Nam                              202000000.0  2.942487e+08
# Yemen                                     50000.0  1.295200e+06
# Zambia                                    49200.0  3.097925e+05
# Zimbabwe                                  18000.0  3.046000e+04
#
# [185 rows x 2 columns]

# %%
# country use python
group["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
group["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python"))
# Out:
# Country
# Afghanistan  1240     False
#              1327     False
#              1377      True
#              1565      True
#              2137       NaN
#                       ...
# Zimbabwe     53302     True
#              56034     True
#              57111     True
#              58144     True
#              63995     True
# Name: LanguageHaveWorkedWith, Length: 58930, dtype: object

# %%
# people doing job in country
country_job = df["Country"].value_counts()

# f=["LanguageHaveWorkedWith"].str.contains("Python").value_counts()
# print(f)

print(country_job)
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
country_use_python= group["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
country_use_python
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
# it return the no. of people work in a country in specific language
python_df=pd.concat([country_job,country_use_python],axis='columns',)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            11095
# Germany                                              4947
# India                                                4231
# United Kingdom of Great Britain and Northern Ir...   3224
# Ukraine                                              2672
# ...                                                   ...
# Micronesia, Federated States of...                      1
# Nauru                                                   1
# Chad                                                    1
# Djibouti                                                1
# Solomon Islands                                         1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              6251
# Germany                                                               2647
# ...

# %%
python_df.rename(columns={"count":"employee count" ,"LanguageHaveWorkedWith" :"python employees"}, inplace=True)

# type(df.loc[0,"employee count"])

# %%
# add the python employee percentage in the country
python_df["python_emp%"] = (python_df["python employees"] / python_df["employee count"])*100

python_df
# Out:
#                                                     employee count  \
# Country
# United States of America                                     11095
# Germany                                                       4947
# India                                                         4231
# United Kingdom of Great Britain and Northern Ir...            3224
# Ukraine                                                       2672
# ...                                                            ...
# Micronesia, Federated States of...                               1
# Nauru                                                            1
# Chad                                                             1
# Djibouti                                                         1
# Solomon Islands                                                  1
#
#                                                     python employees  \
# Country
# United States of America                                        6251
# ...

# %%
# sort according to the any particular column
python_df.sort_values(by="Country" , inplace=True)
python_df
# Out:
#                                       employee count  python employees  \
# Country
# Afghanistan                                       56                26
# Albania                                           49                10
# Algeria                                           77                37
# Andorra                                           15                 8
# Angola                                            20                 9
# ...                                              ...               ...
# Venezuela, Bolivarian Republic of...              69                25
# Viet Nam                                         296               138
# Yemen                                             18                10
# Zambia                                            15                 8
# Zimbabwe                                          26                17
#
#                                       python_emp%
# Country
# ...
