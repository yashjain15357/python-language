# %% [markdown]
# Clean the data

# %% [markdown]
# Remve the roe , columns and replace element by NaN value

# %%
import pandas as pd
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df=pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# remove the rows

# %%
# remove the columns by columns name
# df.drop(columns="first")

# %%
# remove the rows by index attribute
# df.drop(index=[2],inplace=True)
# df

# %%
# remove the specific element

# df.at[1, "age"] = np.nan
# df

# %% [markdown]
# play with NaN value

# %%
# Remove all rows that contain NaN values from the dataset
df.dropna()
# it needs a inplace=True for the change in a dataset
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# NOTE: it the survey data use a NA value Missing value etc so for cleaning data first replace NA or Missing etc. value with NaN

# %%
df.replace("NA",np.nan,inplace=True)
df.replace("Missing",np.nan,inplace=True)
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# it return a tabel in boolean for 
# it replace the NaN vale with the True and non-NaN value with False
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
# "any" (default) → Drops rows/columns if any value is NaN
# 0 (default) → Removes rows with NaN
df.dropna(axis=0, how='any',  inplace=False)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# "all" → Drops rows/columns only if all values are NaN
# 1/"columns" → Removes columns with NaN
df.dropna(axis="columns", how='all',  inplace=False)
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
# "all" → Drops rows/columns only if all values are NaN
# 1/"columns" → Removes columns with NaN

# subset:-check for NaN (instead of all)

df.dropna(how='any', subset=["email","age"], inplace=False)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# fill a  NaN value with another value all the data type
df.fillna(-1)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                       -1  36
# 4     -1       -1                       -1  -1
# 5     -1       -1      Anonymous@email.com  -1
# 6     -1       -1                       -1  -1

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
# df["age"].mean()

# %%
# df["age"]=df["age"].astype("Int64")
# df.dtypes

# %%
df["age"]=df["age"].astype(float) # it type cast he data another data type 
df.dtypes # check the data type of the columns
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %% [markdown]
# fill the mean value at he place of the NaN value for data cleaning process

# %%
me=df["age"].mean()
df["age"]=df["age"].replace(np.nan,me)
df
# Out:
#    first     last                    email    age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.00
# 1   Jane      Doe        JaneDoe@email.com  55.00
# 2   John      Doe        JohnDoe@email.com  63.00
# 3  Chris  Schafer                     None  36.00
# 4    NaN      NaN                      NaN  46.75
# 5   None      NaN      Anonymous@email.com  46.75
# 6    NaN      NaN                      NaN  46.75

# %% [markdown]
# work on csv file

# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv(r'C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_public.csv', index_col='ResponseId', na_values=na_vals )
schema_df = pd.read_csv(r'C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_schema.csv', index_col='qid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 na_vals = ['NA', 'Missing']
# ----> 2 df = pd.read_csv(r'C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_public.csv', index_col='ResponseId', na_values=na_vals )
#       3 schema_df = pd.read_csv(r'C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_schema.csv', index_col='qid')
#
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
# it return a all unique value present in columns
df['YearsCode'].unique()
# Out:
# array([nan, '20', '37', '4', '9', '10', '7', '1', '15', '30', '31', '6',
#        '12', '22', '5', '36', '25', '44', '24', '18', '3', '8',
#        'More than 50 years', '11', '29', '40', '39', '2', '42', '34',
#        '19', '35', '16', '33', '13', '23', '14', '28', '17', '21', '43',
#        '46', '26', '32', '41', '45', '27', '38', '50', '48', '47',
#        'Less than 1 year', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].replace({
    "Less than 1 year": 0,
    "More than 50 years": 51
})

# df['YearsCode'].dtypes
df["YearsCode"]=df["YearsCode"].astype(float)
me= df["YearsCode"].mean()
print(me)
df['YearsCode']=df['YearsCode'].fillna(me)
df["YearsCode"]=df["YearsCode"].astype(int)
df['YearsCode'].unique()
# Out:
# 14.180692880174824
# array([14, 20, 37,  4,  9, 10,  7,  1, 15, 30, 31,  6, 12, 22,  5, 36, 25,
#        44, 24, 18,  3,  8, 51, 11, 29, 40, 39,  2, 42, 34, 19, 35, 16, 33,
#        13, 23, 28, 17, 21, 43, 46, 26, 32, 41, 45, 27, 38, 50, 48, 47,  0,
#        49])
