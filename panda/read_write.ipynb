# %%
import pandas as pd

# %%
ds = pd.read_csv(r"C:\Users\YASH JAIN\Documents\New Folder\OneDrive\Desktop\CodeBox\python language\panda\data\survey_results_public.csv")
ds.head(8)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
# 7     Less than once per year
#
# ...

# %% [markdown]
# Read , Write and export the file

# %%
# make a dataframe from the present dataframe
filt = ds["Country"]=="India"
india=ds.loc[filt]

# %%
# save a file in .csv formate
india.to_csv("india.csv")

# %%
# india.to_csv("india.tsv",sep="\t")

# %%
india.to_excel("india.xlsx")

# %%
india.to_json("india.json")

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# this create a issue for the @ present in a password
# eng= create_engine("postgresql://yash:gg@15357@localhost:5555/basedata")
# solution:
# use '%40' at a place of '@'
# use connect_args={"passord": "your password"}

# %%
# eng= create_engine("postgresql://yash:Yash%4015357@localhost:3306/basedata")
eng= create_engine("postgresql://root:Yash%4015357@127.0.0.1:3306/basedata",connect_args={"password":"Yash@15357"})

# %%
# india.to_sql("basedata",eng)
