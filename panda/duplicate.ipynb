# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\YASH JAIN\Downloads\Titanic-Dataset.csv')

# %%
df.duplicated(keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated(subset=["Age","sex"]).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26700\3643849440.py in ?()
# ----> 1 df.duplicated(subset=["Age","sex"]).head(10)
#       2
#
# c:\Users\YASH JAIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#    6953             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['sex'], dtype='object')
